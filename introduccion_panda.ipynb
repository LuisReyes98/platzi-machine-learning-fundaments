# %%
import pandas as pd

# %%
series = pd.Series( [5,10, 15, 20, 25 ])
series
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series[3]
# Out:
# 20

# %%
cad = pd.Series( ['p', 'l', 'a', 't', 'z', 'i'])
cad
# Out:
# 0    p
# 1    l
# 2    a
# 3    t
# 4    z
# 5    i
# dtype: object

# %%
lst = ['Hola', 'mundo', 'róbotico']
df = pd.DataFrame(lst)
df
# Out:
#           0
# 0      Hola
# 1     mundo
# 2  róbotico

# %%
data = {
  'Nombre': ['Juan', 'Ana', 'Jose', 'Arturo'],
  'Edad': [25, 18, 23, 27],
  'Pais': ['MX', 'CO', 'BR', 'MX']
}
df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad Pais
# 0    Juan    25   MX
# 1     Ana    18   CO
# 2    Jose    23   BR
# 3  Arturo    27   MX

# %%
print(df[['Nombre', 'Pais']])
# Out:
#    Nombre Pais
# 0    Juan   MX
# 1     Ana   CO
# 2    Jose   BR
# 3  Arturo   MX

# %%
data = pd.read_csv('canciones-2018.csv')
data.head(5)
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
# artista = data.artists
artista = data['artists']
artista[5]
# Out:
# 'Post Malone'

# %%
info = data.iloc[15]
info
# Out:
# id                     3GCdLUSnKSMJhs4Tj6CV3
# name                All The Stars (with SZA)
# artists                       Kendrick Lamar
# danceability                           0.698
# energy                                 0.633
# key                                      8.0
# loudness                              -4.946
# mode                                     1.0
# speechiness                           0.0597
# acousticness                          0.0605
# instrumentalness                    0.000194
# liveness                              0.0926
# valence                                0.552
# tempo                                 96.924
# duration_ms                         232187.0
# time_signature                           4.0
# Name: 15, dtype: object

# %%
data.tail()
# Out:
#                        id                               name       artists  \
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 95         0.684   0.619  10.0    -7.005   1.0       0.0386        0.0716
# 96         0.638   0.658   3.0    -6.318   1.0       0.0456        0.2450
# 97         0.552   0.760   0.0    -4.706   1.0       0.3420        0.0733
# 98         0.258   0.437  11.0    -6.593   0.0       0.0390        0.1010
# 99         0.553   0.586  11.0    -6.319   1.0       0.0362        0.6970
#
# ...

# %%
data.shape
# Out:
# (100, 16)

# %%
data.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
data['tempo'].describe()
# Out:
# count    100.000000
# mean     119.904180
# std       28.795984
# min       64.934000
# 25%       95.730750
# 50%      120.116000
# 75%      140.022750
# max      198.075000
# Name: tempo, dtype: float64

# %%
data.sort_index(axis=0, ascending=False)
# Out:
#                        id                               name       artists  \
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# ..                    ...                                ...           ...
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
#
# ...

# %% [markdown]
# ## Reto
#
# ordernar 3 columnas de forma ascendente

# %%
subdata = data[['artists', 'name', 'duration_ms']]
subdata
# Out:
#          artists                               name  duration_ms
# 0          Drake                         God's Plan     198973.0
# 1   XXXTENTACION                               SAD!     166606.0
# 2    Post Malone         rockstar (feat. 21 Savage)     218147.0
# 3    Post Malone       Psycho (feat. Ty Dolla $ign)     221440.0
# 4          Drake                     In My Feelings     217925.0
# ..           ...                                ...          ...
# 95     Zac Efron                  Rewrite The Stars     217440.0
# 96  Clean Bandit  I Miss You (feat. Julia Michaels)     205748.0
# 97     DJ Khaled                         No Brainer     260000.0
# 98          ZAYN        Dusk Till Dawn - Radio Edit     239000.0
# 99    Dean Lewis                         Be Alright     196373.0
#
# [100 rows x 3 columns]

# %%
subdata.sort_values(by='duration_ms', axis=0, ascending=True)
# Out:
#          artists                                name  duration_ms
# 94  XXXTENTACION  Everybody Dies In Their Nightmares      95467.0
# 28  XXXTENTACION                      Jocelyn Flores     119133.0
# 38  XXXTENTACION                             changes     121887.0
# 22         Bazzi                                Mine     131064.0
# 18  XXXTENTACION                           Moonlight     135090.0
# ..           ...                                 ...          ...
# 29    Ed Sheeran                             Perfect     263400.0
# 74        G-Eazy               Him & I (with Halsey)     268867.0
# 73         Migos                     Walk It Talk It     276147.0
# 42  Travis Scott                          SICKO MODE     312820.0
# 21    Nio Garcia                     Te Bot? - Remix     417920.0
#
# [100 rows x 3 columns]

# %%
subdata.sort_values(by='name', axis=0, ascending=True)
# Out:
#                 artists                                               name  \
# 77          Sofia Reyes        1, 2, 3 (feat. Jason Derulo & De La Ghetto)
# 60           Anne-Marie                                               2002
# 34           Luis Fonsi                                    ?chame La Culpa
# 15       Kendrick Lamar                           All The Stars (with SZA)
# 47         Selena Gomez  Back To You - From 13 Reasons Why ? Season 2 S...
# ..                  ...                                                ...
# 23  5 Seconds of Summer                                         Youngblood
# 38         XXXTENTACION                                            changes
# 80        Billie Eilish                               lovely (with Khalid)
# 16        Ariana Grande                               no tears left to cry
# 2           Post Malone                         rockstar (feat. 21 Savage)
#
#     duration_ms
# 77     201526.0
# 60     186987.0
# ...

# %%
subdata.sort_values(by='artists', axis=0, ascending=True)
# Out:
#                 artists                                    name  duration_ms
# 23  5 Seconds of Summer                              Youngblood     203418.0
# 55              6ix9ine  FEFE (feat. Nicki Minaj & Murda Beatz)     179405.0
# 88               Anitta                                Downtown     193456.0
# 60           Anne-Marie                                    2002     186987.0
# 65        Ariana Grande                          God is a woman     197547.0
# ..                  ...                                     ...          ...
# 38         XXXTENTACION                                 changes     121887.0
# 98                 ZAYN             Dusk Till Dawn - Radio Edit     239000.0
# 95            Zac Efron                       Rewrite The Stars     217440.0
# 14                 Zedd                              The Middle     184732.0
# 35         benny blanco         Eastside (with Halsey & Khalid)     173800.0
#
# [100 rows x 3 columns]
